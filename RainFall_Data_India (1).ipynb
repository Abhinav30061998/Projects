# %% [markdown]
# ###### RainFall Data INDIA
#
# #Allocating Libraries

# %%
#Here We Analyse District Wise Data Only

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("C:/Users/Abhinav Thanippadath/Documents/Abhinav Thanippadath.V/Abhinav_Official/Analyst Work/PYTHON BUSINESS ANALYTICS/Rainfall_India/district wise rainfall normal.csv") 
df.head(10)
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN    FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3   57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7   26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7   15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2   80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3   79.5  105.9  216.5
# 5            ARUNACHAL PRADESH  SUBANSIRI F.D   28.0   48.3   85.3  101.5
# 6            ARUNACHAL PRADESH          TIRAP   42.2   72.7  141.0  316.9
# 7            ARUNACHAL PRADESH  ANJAW (LOHIT)   42.2   80.8  176.4  358.5
# 8            ARUNACHAL PRADESH   LOWER DIBANG   83.7  153.9  303.5  383.6
# 9            ARUNACHAL PRADESH      CHANGLANG   70.3  170.9  367.9  554.4
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# ...

# %%
# Here We Can See That,Each Attribute Count,Mean,std,min,25%,50%,75%,max

df.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %%
#Histographic Representation Of District 

plt.hist(df['DISTRICT'],bins = 15)
plt.yscale('log')
plt.show()

# %%
# 1- ANNUAL DATA Representation In Plot Method
# 2- ANNUAL DATA Representation In Histogram Method

plt.subplot(1,2,1)
plt.plot(df['ANNUAL'])
plt.yscale('log')
plt.show()

plt.subplot(1,2,2)
plt.hist(df['ANNUAL'])
plt.yscale('log')
plt.show()

# %%
# Histogramic Representation Of ANNUAL DATA 
#Importance Of 'bins' 

plt.hist(df['ANNUAL'], bins = 50)
plt.yscale('log')
plt.show()

# %%
# Histographic Representation Of State UT Name

plt.hist(df['STATE_UT_NAME'],bins = 15)
plt.yscale('log')
plt.show()

# %%
# Various District Wise RainFall DATA Of Every Month

plt.figure(1)

plt.title('JANUARY')
plt.plot(df['JAN'])
plt.yscale('log')

plt.figure(2)
plt.title('FEBRUARY')
plt.plot(df['FEB'])
plt.yscale('log')

plt.figure(3)
plt.title('MARCH')
plt.plot(df['MAR'])
plt.yscale('log')

plt.figure(4)
plt.title('APRIL')
plt.plot(df['APR'])
plt.yscale('log')

plt.show()

# %%
plt.figure(5)
plt.title('MAY')
plt.plot(df['MAY'])
plt.yscale('log')

plt.figure(6)
plt.title('JUNE')
plt.plot(df['JUN'])
plt.yscale('log')

plt.figure(7)
plt.title('JULY')
plt.plot(df['JUL'])
plt.yscale('log')

plt.figure(8)
plt.title('AUGUST')
plt.plot(df['AUG'])
plt.yscale('log')

plt.show()

# %%
plt.figure(9)
plt.title('SEPTEMBER')
plt.plot(df['SEP'])
plt.yscale('log')

plt.figure(10)
plt.title('OCTOBER')
plt.plot(df['OCT'])
plt.yscale('log')

plt.figure(11)
plt.title('NOVEMBER')
plt.plot(df['NOV'])
plt.yscale('log')

plt.figure(12)
plt.title('DECEMBER')
plt.plot(df['DEC'])
plt.yscale('log')

plt.show()

# %%
# Various District Wise RainFall DATA Of JAN-FEB/MAR-MAY/JUN-SEP/OCT-DEC



plt.figure(1)
plt.subplot(2,2,1)
plt.title('JAN-FEB')
plt.scatter(df['Jan-Feb'],df['DISTRICT'])

plt.figure(2)
plt.subplot(2,2,2)
plt.title('MAR-MAY')
plt.scatter(df['Mar-May'],df['DISTRICT'])

plt.figure(3)
plt.subplot(2,2,3)
plt.title('JUN-SEP')
plt.scatter(df['Jun-Sep'],df['DISTRICT'])

plt.figure(4)
plt.subplot(2,2,4)
plt.title('OCT-DEC')
plt.plot(df['Oct-Dec'],df['DISTRICT'])

plt.show()

# %%
# Here We Are Seperating District Data

District = df['DISTRICT']
District.head()
# Out:
# 0          NICOBAR
# 1    SOUTH ANDAMAN
# 2    N & M ANDAMAN
# 3            LOHIT
# 4       EAST SIANG
# Name: DISTRICT, dtype: object

# %%
# Here We Are Considering TYPE Of Attribute DISTRICT

type(df['DISTRICT'])
# Out:
# pandas.core.series.Series

# %%
# Here We Are Specifying Shape Of DISTRICT Attribute 

df['DISTRICT'].shape
# Out:
# (641,)

# %%
#This Is A Main Section, Here We Are Combining DISTRICT And ANNUAL Data Together

District_Annual = df[['DISTRICT','ANNUAL']]
District_Annual.head()
# Out:
#         DISTRICT  ANNUAL
# 0        NICOBAR  2805.2
# 1  SOUTH ANDAMAN  3015.7
# 2  N & M ANDAMAN  2913.3
# 3          LOHIT  3043.8
# 4     EAST SIANG  4034.7

# %%
#Scatteplot Representation
#Here We Are Trying To Display District_Annual Data

plt.title('District And Annual Data')
#Naming X-Axis and Y-Axis
plt.xlabel('DISTRICT')
plt.ylabel('ANNUAL')
plt.scatter(df['DISTRICT'],df['ANNUAL'])
plt.show()

# %%
#Line Graph Method Representation
#Here We Are Trying To Display District_Annual Data

plt.title('District And Annual Data')
#Naming X-Axis and Y-Axis
plt.xlabel('DISTRICT')
plt.ylabel('ANNUAL')
plt.plot(df['DISTRICT'],df['ANNUAL'])
plt.show()

# %%
#Here We Are Successfully Concatinate All Together KERALA RAINFALL Data

Kerala = df[df['STATE_UT_NAME']=="KERALA"]
Kerala.head(14)
# Out:
#     STATE_UT_NAME        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN  \
# 626        KERALA       ALAPPUZHA  17.5  27.9  45.1  134.0  298.7  593.0
# 627        KERALA          CANNUR   2.5   2.0   7.6   57.9  235.0  852.4
# 628        KERALA       ERNAKULAM  13.2  18.8  31.2  112.0  300.4  696.4
# 629        KERALA        KOTTAYAM  13.0  24.9  42.3  136.1  281.8  649.1
# 630        KERALA       KOZHIKODE   2.3   3.9  15.1   80.9  256.6  895.8
# 631        KERALA      MALAPPURAM   1.7   3.9  12.7   86.8  221.3  660.9
# 632        KERALA        PALAKKAD   2.9   6.5  22.5   98.7  158.7  464.3
# 633        KERALA          KOLLAM  17.5  33.7  62.6  158.5  248.5  457.7
# 634        KERALA        THRISSUR   3.4   7.5  17.0   79.2  289.1  707.4
# 635        KERALA   THIRUVANANTHA  19.3  21.1  35.5  116.7  216.6  338.7
# 636        KERALA          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6
# 637        KERALA        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6
# ...

# %%
Kerala
# Out:
#     STATE_UT_NAME        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN  \
# 626        KERALA       ALAPPUZHA  17.5  27.9  45.1  134.0  298.7  593.0
# 627        KERALA          CANNUR   2.5   2.0   7.6   57.9  235.0  852.4
# 628        KERALA       ERNAKULAM  13.2  18.8  31.2  112.0  300.4  696.4
# 629        KERALA        KOTTAYAM  13.0  24.9  42.3  136.1  281.8  649.1
# 630        KERALA       KOZHIKODE   2.3   3.9  15.1   80.9  256.6  895.8
# 631        KERALA      MALAPPURAM   1.7   3.9  12.7   86.8  221.3  660.9
# 632        KERALA        PALAKKAD   2.9   6.5  22.5   98.7  158.7  464.3
# 633        KERALA          KOLLAM  17.5  33.7  62.6  158.5  248.5  457.7
# 634        KERALA        THRISSUR   3.4   7.5  17.0   79.2  289.1  707.4
# 635        KERALA   THIRUVANANTHA  19.3  21.1  35.5  116.7  216.6  338.7
# 636        KERALA          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6
# 637        KERALA        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6
# ...
