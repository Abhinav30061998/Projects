# %%
#Meat Consumption WorldWide Data

#Allocating Libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv("C:/Users/Abhinav Thanippadath/Documents/Abhinav Thanippadath.V/Abhinav_Official/Analyst Work/archive/meat_consumption_worldwide.csv")
df.head(10)
# Out:
#   LOCATION SUBJECT MEASURE  TIME      Value
# 0      AUS    BEEF  KG_CAP  1991  27.721815
# 1      AUS    BEEF  KG_CAP  1992  26.199591
# 2      AUS    BEEF  KG_CAP  1993  26.169094
# 3      AUS    BEEF  KG_CAP  1994  25.456134
# 4      AUS    BEEF  KG_CAP  1995  25.340226
# 5      AUS    BEEF  KG_CAP  1996  27.259104
# 6      AUS    BEEF  KG_CAP  1997  28.802913
# 7      AUS    BEEF  KG_CAP  1998  26.590477
# 8      AUS    BEEF  KG_CAP  1999  27.918283
# 9      AUS    BEEF  KG_CAP  2000  26.354624

# %%
df.describe()
# Out:
#                TIME         Value
# count  13760.000000  1.376000e+04
# mean    2008.175291  1.861701e+03
# std       10.600740  9.385656e+03
# min     1990.000000  1.669000e-09
# 25%     1999.000000  3.475390e+00
# 50%     2008.000000  2.313983e+01
# 75%     2017.000000  2.967790e+02
# max     2026.000000  1.316073e+05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13760 entries, 0 to 13759
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LOCATION  13760 non-null  object
#  1   SUBJECT   13760 non-null  object
#  2   MEASURE   13760 non-null  object
#  3   TIME      13760 non-null  int64
#  4   Value     13760 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 537.6+ KB

# %%
plt.boxplot(df['Value'])
plt.show()

# %%
plt.boxplot(df['TIME'])
plt.show()

# %%
df['SUBJECT'].describe()
# Out:
# count     13760
# unique        4
# top       SHEEP
# freq       3457
# Name: SUBJECT, dtype: object

# %%
plt.subplot(121)
plt.boxplot(df['Value'])

plt.subplot(122)
plt.boxplot(df['Value'])
plt.yscale('log')
plt.show()

# %%
plt.subplot(121)
plt.boxplot(df['TIME'])
plt.show()

# %%
plt.hist(df['LOCATION'])
plt.yscale('log')
plt.show()

# %%
plt.hist(df['SUBJECT'])
plt.yscale('log')
plt.show()

# %%
#seaborn

import seaborn as sns

sns.set_style("whitegrid")
sns.displot(df['TIME'])
plt.show()

# %%
sns.displot(df['Value'])
sns.set_style("ticks")
plt.yscale('log')
plt.show()

# %%
sns.displot(df['TIME'][:2000],rug=True)
plt.show()

# %%
#Boxplot

sns.boxplot(df['Value'])
plt.title('Value')
plt.show()
# Out:
# C:\Users\Abhinav Thanippadath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['TIME'])
plt.title('Years')
plt.show()
# Out:
# C:\Users\Abhinav Thanippadath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(x=df['TIME'])
sns.displot(y=df['Value'])
plt.show()

# %%
sns.jointplot('SUBJECT','Value',df)
plt.show()
# Out:
# C:\Users\Abhinav Thanippadath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = df[(df.TIME<2020) & (df.SUBJECT=='BEEF')]
sns.jointplot('TIME','SUBJECT',df)
plt.show()
# Out:
# C:\Users\Abhinav Thanippadath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = df[(df.TIME>2021) & (df.SUBJECT=='SHEEP')]
sns.jointplot('TIME','SUBJECT',df)
plt.show()
# Out:
# C:\Users\Abhinav Thanippadath\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
